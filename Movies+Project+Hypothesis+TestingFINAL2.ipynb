# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %matplotlib inline

# %%
data=pd.read_csv('merge9.csv')
dtype={'userid': int}
dtype={'movieid':int}
dtype={'occupation':int}
# Out:
# C:\Users\zmeli\Anaconda3.1\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (0,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head(10)
# Out:
#   userid  movieid  rating    timestamp  occupation    genres1    genres2  \
# 0   2304      1.0     4.0  974500728.0        12.0  Adventure  Animation
# 1   3526      1.0     5.0  966903972.0         2.0  Adventure  Animation
# 2   3196      1.0     4.0  970939946.0         4.0  Adventure  Animation
# 3   1057      1.0     5.0  974952896.0        17.0  Adventure  Animation
# 4   3195      1.0     3.0  968641752.0         4.0  Adventure  Animation
# 5   5662      1.0     4.0  958933731.0        10.0  Adventure  Animation
# 6    132      1.0     5.0  977427737.0        17.0  Adventure  Animation
# 7   1545      1.0     3.0  974744628.0        20.0  Adventure  Animation
# 8   2300      1.0     4.0  974498526.0        13.0  Adventure  Animation
# 9   1242      1.0     3.0  976308358.0         0.0  Adventure  Animation
#
#     genres3 genres4  genres5 genres6 genres7 genres8  genres9  genres10  \
# 0  Children  Comedy  Fantasy     NaN     NaN     NaN      NaN       NaN
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data # we dropped timestamp because we won't need it
# Out:
#         userid  movieid  rating     timestamp  occupation      genres1  \
# 0         2304      1.0     4.0  9.745007e+08        12.0    Adventure
# 1         3526      1.0     5.0  9.669040e+08         2.0    Adventure
# 2         3196      1.0     4.0  9.709399e+08         4.0    Adventure
# 3         1057      1.0     5.0  9.749529e+08        17.0    Adventure
# 4         3195      1.0     3.0  9.686418e+08         4.0    Adventure
# 5         5662      1.0     4.0  9.589337e+08        10.0    Adventure
# 6          132      1.0     5.0  9.774277e+08        17.0    Adventure
# 7         1545      1.0     3.0  9.747446e+08        20.0    Adventure
# 8         2300      1.0     4.0  9.744985e+08        13.0    Adventure
# 9         1242      1.0     3.0  9.763084e+08         0.0    Adventure
# 10        5009      1.0     3.0  9.625861e+08        16.0    Adventure
# 11        5555      1.0     4.0  9.594587e+08        10.0    Adventure
# ...

# %%
data.drop(['Column1','_1','_2','_3'],axis=1,inplace=True)
data
# Out:
#         userid  movieid  rating     timestamp  occupation      genres1  \
# 0         2304      1.0     4.0  9.745007e+08        12.0    Adventure
# 1         3526      1.0     5.0  9.669040e+08         2.0    Adventure
# 2         3196      1.0     4.0  9.709399e+08         4.0    Adventure
# 3         1057      1.0     5.0  9.749529e+08        17.0    Adventure
# 4         3195      1.0     3.0  9.686418e+08         4.0    Adventure
# 5         5662      1.0     4.0  9.589337e+08        10.0    Adventure
# 6          132      1.0     5.0  9.774277e+08        17.0    Adventure
# 7         1545      1.0     3.0  9.747446e+08        20.0    Adventure
# 8         2300      1.0     4.0  9.744985e+08        13.0    Adventure
# 9         1242      1.0     3.0  9.763084e+08         0.0    Adventure
# 10        5009      1.0     3.0  9.625861e+08        16.0    Adventure
# 11        5555      1.0     4.0  9.594587e+08        10.0    Adventure
# ...

# %%
 #HYPOTHESIS : People's movie genre choice changes according to their occupation.--- There is a relation between occupation and choice of genre.

# %%
d1 = data[(data.genres1=='Action')|(data.genres2=='Action') ]

# %%
d1.head()
# Out:
#      userid  movieid  rating    timestamp  occupation genres1 genres2  \
# 3722    783      6.0     2.0  975702105.0         4.0  Action   Crime
# 3723   2288      6.0     2.0  974521161.0        10.0  Action   Crime
# 3724   2393      6.0     3.0  974382722.0        13.0  Action   Crime
# 3725   5029      6.0     4.0  962565903.0         4.0  Action   Crime
# 3726   2276      6.0     5.0  978811276.0        13.0  Action   Crime
#
#        genres3 genres4 genres5 genres6 genres7 genres8  genres9  genres10
# 3722  Thriller     NaN     NaN     NaN     NaN     NaN      NaN       NaN
# 3723  Thriller     NaN     NaN     NaN     NaN     NaN      NaN       NaN
# 3724  Thriller     NaN     NaN     NaN     NaN     NaN      NaN       NaN
# 3725  Thriller     NaN     NaN     NaN     NaN     NaN      NaN       NaN
# 3726  Thriller     NaN     NaN     NaN     NaN     NaN      NaN       NaN

# %%
d1['rating'].count()  #rating count for action movies
# Out:
# 250355

# %%
d1academic = d1[(d1.occupation==1.0)]
d1academic.head(3)
# Out:
#      userid  movieid  rating    timestamp  occupation genres1 genres2  \
# 3731   5647      6.0     4.0  958873909.0         1.0  Action   Crime
# 3750   5473      6.0     4.0  959886046.0         1.0  Action   Crime
# 3813   3771      6.0     4.0  966049395.0         1.0  Action   Crime
#
#        genres3 genres4 genres5 genres6 genres7 genres8  genres9  genres10
# 3731  Thriller     NaN     NaN     NaN     NaN     NaN      NaN       NaN
# 3750  Thriller     NaN     NaN     NaN     NaN     NaN      NaN       NaN
# 3813  Thriller     NaN     NaN     NaN     NaN     NaN      NaN       NaN

# %%
d1academic['rating'].sum() ##rating count for action movies for academic educators
# Out:
# 61196.0

# %%
d1academic.sum()
# Out:
# movieid       3.237070e+07
# rating        6.119600e+04
# timestamp     1.752901e+13
# occupation    1.806300e+04
# genres9       0.000000e+00
# genres10      0.000000e+00
# dtype: float64

# %%
d1academic['occupation'].count() #NUMBER OF EDUCATORS VOTED
# Out:
# 18063

# %%
d1artist= d1[(d1.occupation==2.0)]
d1artist['rating'].sum()
# Out:
# 37986.0

# %%
d1artist['occupation'].count() #NUMBER OF ARTISTS VOTED
# Out:
# 10947

# %%
d1colstu= d1[(d1.occupation==4.0)]
d1colstu['rating'].sum()
# Out:
# 119895.0

# %%
d1colstu['occupation'].count()  #NUMBER OF STUDENTS VOTED
# Out:
# 34627

# %%
d1doctor= d1[(d1.occupation==6.0)] 
d1doctor['rating'].sum()
# Out:
# 29737.0

# %%
d1doctor['occupation'].count() #NUMBER OF DOCTORS VOTED
# Out:
# 8336

# %%
d1programmer= d1[(d1.occupation==12.0)]
d1programmer['rating'].sum()
# Out:
# 59979.0

# %%
d1programmer['occupation'].count() #NUMBER OF PROGRAMMERS VOTED
# Out:
# 16721

# %%
d1writer= d1[(d1.occupation==20.0)] 
d1writer['rating'].sum()
# Out:
# 40718.0

# %%
d1writer['occupation'].count() #NUMBER OF WRITERS VOTED
# Out:
# 12187

# %%
d1.groupby('occupation')['rating'].count() ## What is the sum of ratings of ACTION movies to each occupation
# Out:
# occupation
# 0.0     32093
# 1.0     18063
# 2.0     10947
# 3.0      6849
# 4.0     34627
# 5.0      6244
# 6.0      8336
# 7.0     27801
# 8.0       838
# 9.0      2041
# 10.0     6166
# 11.0     4605
# 12.0    16721
# 13.0     2692
# 14.0    13070
# 15.0     6282
# 16.0    11466
# 17.0    22582
# 18.0     3131
# 19.0     3604
# 20.0    12187
# Name: rating, dtype: int64

# %%
grouped = d1.groupby('rating').agg({"occupation": [sum,min,max]})
grouped.columns=["_".join(x) for x in grouped.columns.ravel()]
grouped.head()
# Out:
#         occupation_sum  occupation_min  occupation_max
# rating
# 1.0           122751.0             0.0            20.0
# 2.0           246221.0             0.0            20.0
# 3.0           567164.0             0.0            20.0
# 4.0           705279.0             0.0            20.0
# 5.0           419610.0             0.0            20.0

# %%
d2 = data[(data.genres1=='Animation')|(data.genres2=='Animation')|(data.genres2=='Animation') ]

# %%
d2academic= d2[(d2.occupation==1.0)] #NUMBER OF EDUCATORS VOTED 
d2academic['occupation'].count()
# Out:
# 2702

# %%
d2artist= d2[(d2.occupation==2.0)] #NUMBER OF ARTISTS VOTED 
d2artist['occupation'].count()
# Out:
# 1769

# %%
d2student= d2[(d2.occupation==4.0)] #NUMBER OF STUDENTS VOTED 
d2student['occupation'].count()
# Out:
# 5684

# %%
d2doctor= d2[(d2.occupation==6.0)] #NUMBER OF DOCTORS VOTED 
d2doctor['occupation'].count()
# Out:
# 1307

# %%
d2programmer= d2[(d2.occupation==12.0)] #NUMBER OF PROGRAMMERS VOTED 
d2programmer['occupation'].count()
# Out:
# 2111

# %%
d2writer= d2[(d2.occupation==20.0)] #NUMBER OF WRITERS VOTED 
d2writer['occupation'].count()
# Out:
# 2166

# %%
d2.groupby('occupation').sum()  ## What is the sum of ratings of ANIMATION to each occupationd2.groupby('occupation')['rating'].sum()
# Out:
#               movieid   rating     timestamp  genres9  genres10
# occupation
# 0.0         7684979.0  16942.0  4.467008e+12      NaN       NaN
# 1.0         4676174.0  10020.0  2.623509e+12      NaN       NaN
# 2.0         3007691.0   6418.0  1.719422e+12      NaN       NaN
# 3.0         1822283.0   4243.0  1.070722e+12      NaN       NaN
# 4.0         9726143.0  20818.0  5.532842e+12      NaN       NaN
# 5.0         1358828.0   2918.0  7.496254e+11      NaN       NaN
# 6.0         2264593.0   4816.0  1.268273e+12      NaN       NaN
# 7.0         5030062.0  10543.0  2.761093e+12      NaN       NaN
# 8.0          170380.0    345.0  9.446758e+10      NaN       NaN
# 9.0          956993.0   2218.0  5.695146e+11      NaN       NaN
# 10.0        2952436.0   6128.0  1.720969e+12      NaN       NaN
# 11.0        1040659.0   2260.0  5.871181e+11      NaN       NaN
# 12.0        3796135.0   7806.0  2.053112e+12      NaN       NaN
# ...

# %%
d2['rating'].count()#rating count for animation movies
# Out:
# 35274

# %%
plt.title('Action for Academic')
plt.hist(d1[d1.occupation==1.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount')

plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.title('Action for Artist')
plt.hist(d1[d1.occupation==2.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount')

plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.title('Action for College Students')
plt.hist(d1[d1.occupation==4.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount')

plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.title('Action for Doctors')
plt.hist(d1[d1.occupation==6.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount')

plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.title('Action for Programmers')
plt.hist(d1[d1.occupation==12.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount')

plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.title('Action for Writers')
plt.hist(d1[d1.occupation==20.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount')

plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#ANIMATION d2
plt.title('Animation for Academic')
plt.hist(d2[d2.occupation==1.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
plt.title('Animation for Artists')
plt.hist(d2[d2.occupation==2.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
plt.title('Animation for Doctors')
plt.hist(d2[d2.occupation==6.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
plt.title('Animation for College Students')
plt.hist(d2[d2.occupation==4.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
plt.title('Animation for Programmers')
plt.hist(d2[d2.occupation==12.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
plt.title('Animation for Writers')
plt.hist(d2[d2.occupation==20.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
#Comedy
d3 = data[ (data.genres1=='Comedy')|(data.genres2=='Comedy')|(data.genres3=='Comedy')|(data.genres4=='Comedy')|(data.genres5=='Comedy')]

# %%
d3.head()
# Out:
#   userid  movieid  rating    timestamp  occupation    genres1    genres2  \
# 0   2304      1.0     4.0  974500728.0        12.0  Adventure  Animation
# 1   3526      1.0     5.0  966903972.0         2.0  Adventure  Animation
# 2   3196      1.0     4.0  970939946.0         4.0  Adventure  Animation
# 3   1057      1.0     5.0  974952896.0        17.0  Adventure  Animation
# 4   3195      1.0     3.0  968641752.0         4.0  Adventure  Animation
#
#     genres3 genres4  genres5 genres6 genres7 genres8  genres9  genres10
# 0  Children  Comedy  Fantasy     NaN     NaN     NaN      NaN       NaN
# 1  Children  Comedy  Fantasy     NaN     NaN     NaN      NaN       NaN
# 2  Children  Comedy  Fantasy     NaN     NaN     NaN      NaN       NaN
# 3  Children  Comedy  Fantasy     NaN     NaN     NaN      NaN       NaN
# 4  Children  Comedy  Fantasy     NaN     NaN     NaN      NaN       NaN

# %%
d3academic= d3[(d3.occupation==1.0)] #NUMBER OF EDUCATORS VOTED 
d3academic['occupation'].count()
# Out:
# 32162

# %%
d3artist= d3[(d3.occupation==2.0)] #NUMBER OF ARTISTS VOTED 
d3artist['occupation'].count()
# Out:
# 19378

# %%
d3student= d3[(d3.occupation==4.0)] #NUMBER OF STUDENTS VOTED 
d3student['occupation'].count()
# Out:
# 52992

# %%
d3doctor= d3[(d3.occupation==6.0)] #NUMBER OF DOCTORS VOTED 
d3doctor['occupation'].count()
# Out:
# 14059

# %%
d3programmer= d3[(d3.occupation==12.0)] #NUMBER OF PROGRAMMERS VOTED 
d3programmer['occupation'].count()
# Out:
# 21420

# %%
d3writer= d3[(d3.occupation==20.0)] #NUMBER OF WRITERS VOTED 
d3writer['occupation'].count()
# Out:
# 23532

# %%
d3.groupby('occupation')['rating'].sum()
# Out:
# occupation
# 0.0     174077.0
# 1.0     112997.0
# 2.0      67812.0
# 3.0      45479.0
# 4.0     184592.0
# 5.0      29541.0
# 6.0      50370.0
# 7.0     134155.0
# 8.0       3492.0
# 9.0      18955.0
# 10.0     35815.0
# 11.0     28079.0
# 12.0     77082.0
# 13.0     16655.0
# 14.0     67618.0
# 15.0     30795.0
# 16.0     58648.0
# 17.0     94707.0
# 18.0     15311.0
# 19.0     19991.0
# 20.0     80607.0
# Name: rating, dtype: float64

# %%
plt.title('Comedy for Academic')
plt.hist(d3[d3.occupation==1.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
plt.title('Comedy for Artist')
plt.hist(d3[d3.occupation==2.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
plt.title('Comedy for College Students')
plt.hist(d3[d3.occupation==4.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
plt.title('Comedy for Doctor')
plt.hist(d3[d3.occupation==6.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
plt.title('Comedy for  Programmer')
plt.hist(d3[d3.occupation==12.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
plt.title('Comedy for  Writer')
plt.hist(d3[d3.occupation==20.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
d4= data[ (data.genres1=='Crime')|(data.genres2=='Crime')|(data.genres3=='Crime')|(data.genres4=='Crime')|(data.genres5=='Crime')|(data.genres6=='Crime')]

# %%
d4
# Out:
#        userid  movieid  rating     timestamp  occupation genres1 genres2  \
# 3722      783      6.0     2.0  9.757021e+08         4.0  Action   Crime
# 3723     2288      6.0     2.0  9.745212e+08        10.0  Action   Crime
# 3724     2393      6.0     3.0  9.743827e+08        13.0  Action   Crime
# 3725     5029      6.0     4.0  9.625659e+08         4.0  Action   Crime
# 3726     2276      6.0     5.0  9.788113e+08        13.0  Action   Crime
# 3727     1718      6.0     5.0  9.747054e+08         4.0  Action   Crime
# 3728     4959      6.0     5.0  9.626369e+08        17.0  Action   Crime
# 3729     3411      6.0     4.0  9.675832e+08         4.0  Action   Crime
# 3730      785      6.0     3.0  9.754307e+08        19.0  Action   Crime
# 3731     5647      6.0     4.0  9.588739e+08         1.0  Action   Crime
# 3732     3209      6.0     4.0  9.685468e+08         0.0  Action   Crime
# 3733     3205      6.0     4.0  9.685651e+08        16.0  Action   Crime
# ...

# %%
d4academic= d4[(d4.occupation==1.0)] #NUMBER OF EDUCATORS VOTED 
d4academic['occupation'].count()
# Out:
# 11451

# %%
d4artist= d4[(d4.occupation==2.0)] #NUMBER OF ARTISTS VOTED 
d4artist['occupation'].count()
# Out:
# 6980

# %%
d4student= d4[(d4.occupation==4.0)] #NUMBER OF STUDENTS VOTED 
d4student['occupation'].count()
# Out:
# 18903

# %%
d4doctor= d4[(d4.occupation==6.0)] #NUMBER OF DOCTORS VOTED 
d4doctor['occupation'].count()
# Out:
# 5023

# %%
d4programmer= d4[(d4.occupation==12.0)] #NUMBER OF PROGRAMMERS VOTED 
d4programmer['occupation'].count()
# Out:
# 8199

# %%
d4writer= d4[(d4.occupation==20.0)] #NUMBER OF WRITERS VOTED 
d4writer['occupation'].count()
# Out:
# 8604

# %%
d4.groupby('occupation')['rating'].sum()
# Out:
# occupation
# 0.0     67534.0
# 1.0     42173.0
# 2.0     26007.0
# 3.0     16778.0
# 4.0     70673.0
# 5.0     11317.0
# 6.0     19088.0
# 7.0     57300.0
# 8.0      1228.0
# 9.0      4687.0
# 10.0     9150.0
# 11.0    11795.0
# 12.0    31038.0
# 13.0     7164.0
# 14.0    28410.0
# 15.0    12666.0
# 16.0    23865.0
# 17.0    38989.0
# 18.0     6234.0
# 19.0     7799.0
# 20.0    31456.0
# Name: rating, dtype: float64

# %%
plt.title('Crime for Academic')
plt.hist(d4[d4.occupation==1.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
plt.title('Crime for Artist')
plt.hist(d4[d4.occupation==2.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
plt.title('Crime for College Students')
plt.hist(d4[d4.occupation==4.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
plt.title('Crime for Doctor')
plt.hist(d4[d4.occupation==6.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
plt.title('Crime for Programmer')
plt.hist(d4[d4.occupation==12.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
plt.title('Crime for Writer')
plt.hist(d4[d4.occupation==20.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
#documentary
d5= data[ (data.genres1=='Documentary')|(data.genres2==' Documentary ')|(data.genres3==' Documentary ')|(data.genres4==' Documentary ')|(data.genres5==' Documentary ')|(data.genres6==' Documentary ') |(data.genres7==' Documentary ')]

# %%
d5academic= d5[(d5.occupation==1.0)] #NUMBER OF ACADEMIC EDUCATORS VOTED 
d5academic['occupation'].count()
# Out:
# 570

# %%
d5artist= d5[(d5.occupation==2.0)] #NUMBER OF ARTISTS VOTED 
d5artist['occupation'].count()
# Out:
# 363

# %%
d5student= d5[(d5.occupation==4.0)] #NUMBER OF STUDENTS VOTED 
d5student['occupation'].count()
# Out:
# 696

# %%
d5doctor= d5[(d5.occupation==6.0)] #NUMBER OF DOCTORS VOTED 
d5doctor['occupation'].count()
# Out:
# 193

# %%
d5programmer= d5[(d5.occupation==12.0)] #NUMBER OF PROGRAMMERS VOTED 
d5programmer['occupation'].count()
# Out:
# 303

# %%
d5writer= d5[(d5.occupation==20.0)] #NUMBER OF WRITERS VOTED 
d5writer['occupation'].count()
# Out:
# 487

# %%
d5.groupby('occupation')['rating'].sum()
# Out:
# occupation
# 0.0     3077.0
# 1.0     2266.0
# 2.0     1471.0
# 3.0      793.0
# 4.0     2740.0
# 5.0      291.0
# 6.0      796.0
# 7.0     1951.0
# 8.0       35.0
# 9.0       93.0
# 10.0     259.0
# 11.0     519.0
# 12.0    1165.0
# 13.0     246.0
# 14.0     897.0
# 15.0     467.0
# 16.0    1129.0
# 17.0    1106.0
# 18.0     191.0
# 19.0     336.0
# 20.0    1937.0
# Name: rating, dtype: float64

# %%
plt.title('Documentary for Academic')
plt.hist(d5[d5.occupation==1.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
plt.title('Documentary for Artist')
plt.hist(d5[d5.occupation==2.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
plt.title('Documentary for College Students')
plt.hist(d5[d5.occupation==4.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
plt.title('Documentary for Doctor')
plt.hist(d5[d5.occupation==6.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
plt.title('Documentary for Programmer')
plt.hist(d5[d5.occupation==12.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
plt.title('Documentary for Writer')
plt.hist(d5[d5.occupation==20.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
#Romance
d6= data[ (data.genres1=='Romance')|(data.genres2=='Romance')|(data.genres3=='Romance')|(data.genres4=='Romance')|(data.genres5=='Romance')|(data.genres6=='Romance') |(data.genres7=='Romance')]

# %%
plt.title('Romance for Academic')
plt.hist(d6[d6.occupation==1.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
plt.title('Romance for Artist')
plt.hist(d6[d6.occupation==2.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
plt.title('Romance for College Students')
plt.hist(d6[d6.occupation==4.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
plt.title('Romance for Doctor')
plt.hist(d6[d6.occupation==6.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
plt.title('Romance for Programmer')
plt.hist(d6[d6.occupation==12.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
plt.title('Romance for Writer')
plt.hist(d6[d6.occupation==20.0].rating)
plt.xlabel('rating')
plt.ylabel('ratingCount');

# %%
d6academic= d6[(d6.occupation==1.0)] #NUMBER OF ACADEMIC EDUCATORS VOTED 
d6academic['occupation'].count()
# Out:
# 18724

# %%
d6artist= d6[(d6.occupation==2.0)] #NUMBER OF ARTISTS VOTED 
d6artist['occupation'].count()
# Out:
# 10111

# %%
d6student= d6[(d6.occupation==4.0)] #NUMBER OF STUDENTS VOTED 
d6student['occupation'].count()
# Out:
# 24488

# %%
d6doctor= d6[(d6.occupation==6.0)] #NUMBER OF DOCTORS VOTED 
d6doctor['occupation'].count()
# Out:
# 7717

# %%
d6programmer= d6[(d6.occupation==12.0)] #NUMBER OF PROGRAMMERS VOTED 
d6programmer['occupation'].count()
# Out:
# 10112

# %%
d6writer= d6[(d6.occupation==20.0)] # NUMBER OF WRITERS VOTED 
d6writer['occupation'].count()
# Out:
# 11928

# %%
d6.groupby('occupation')['rating'].sum()
# Out:
# occupation
# 0.0     88757.0
# 1.0     68303.0
# 2.0     36457.0
# 3.0     25066.0
# 4.0     88070.0
# 5.0     12620.0
# 6.0     28786.0
# 7.0     72578.0
# 8.0      1717.0
# 9.0     12304.0
# 10.0    14384.0
# 11.0    14557.0
# 12.0    37467.0
# 13.0    11377.0
# 14.0    35249.0
# 15.0    15606.0
# 16.0    31631.0
# 17.0    44519.0
# 18.0     6400.0
# 19.0     9053.0
# 20.0    42122.0
# Name: rating, dtype: float64
